# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\BEEBEERUN.csv")
df
# Out:
#        7040  6592  2332  -3680  -8584  -9164  -4832  1580  6388  6956  ...  \
# 0     -1684  4156  7216   5504     -8  -5836  -8980 -7936 -2844  3472  ...
# 1     -9056 -5744   328   5516   6972   4064  -1912 -7628 -9488 -6468  ...
# 2     -5204 -8464 -7868  -3408   2804   6852   6200  1532 -4544 -8772  ...
# 3      3896 -1324 -6788  -8948  -6192   -524   4672  6752  4432 -1072  ...
# 4      6376  6080  1528  -4160  -8240  -8580  -4284  2064  6240  6208  ...
# ...     ...   ...   ...    ...    ...    ...    ...   ...   ...   ...  ...
# 24494 -5628 -8892 -7584  -2488   3276   6700   5872   848 -5520 -9020  ...
# 24495    24 -5444 -8432  -6944  -2344   2564   5412  4508   172 -4808  ...
# 24496  4900   -68 -5580  -8312  -7044  -2640   2872  6316  5244   496  ...
# 24497  6184  4664   140  -5192  -8460  -7416  -2544  3032  6108  5132  ...
# 24498  4112  6852  4940   -428  -5976  -8828  -7344 -2064  3808  6768  ...
#
# ...
